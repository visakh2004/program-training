# %% [markdown]
# <a href="https://colab.research.google.com/github/visakh2004/program-training/blob/main/pythontraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter total monkey (n):"))
k=int(input("Enter total banana a monkey can eat (k):"))
j=int(input("Enter total peanut a monkey can eat (j):"))
m=int(input("Enter total bananas (m):"))
p=int(input("Enter total peanut (p):"))
if p<=0 or n<=0 or m<=0 or k<=0 or j<=0:
  print("Invalid input")
if m%k!=0 and p%j!=0:
 n=n-1
r=(n-((m/k)+(p/j)))
print("Remaining monkey",r)
# Out:
# Enter total monkey (n):20
# Enter total banana a monkey can eat (k):2
# Enter total peanut a monkey can eat (j):3
# Enter total bananas (m):12
# Enter total peanut (p):12
# Remaining monkey 10.0

# %%
a=int(input("enter first number:"))
b=int(input("enter the second number"))
print("a=",a)
print("b=",b)
a=a^b
b=a^b
a=a^b

print("after swapping")
print("a=",a)
print("b=",b)
# Out:
# enter first number:2
# enter the second number5
# a= 2
# b= 5
# after swapping
# a= 5
# b= 2

# %%
print("Using Temp")
a,b=10,5
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=10,5
a,b=b,a
print(a,b)
print("Using + and -")
a,b=10,5
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=10,5
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 5 10
# Using ,
# 5 10
# Using + and -
# 5 10
# Using ^
# 5 10

# %%
N = 10
K = 5
candies = N
order = int(input("Enter number of candies: "))

if order > candies or order <= 0:
    print("INVALID INPUT")
else:
    candies -= order
    print("Number of Candies Sold:", order)
    if candies <= K:
        candies = N
    print("Number of Candies available:", candies)
# Out:
# Enter number of candies: 7
# Number of Candies Sold: 7
# Number of Candies available: 10

# %%
n=int(input("Enter jar capacity:"))
k=int(input("Enter min candies:"))
t=n
i='y'
ts=0
while i!='n':
  x=int(input("Enter candies to sold:"))
  if x>n:
    print("Invalid input")
  else:
    n=n-x
    ts=ts+x
    print("Sold:",x)
    if n<=k:
      n=t
    print("Available candies:",n)
    print("Total sold",ts)
# Out:
# Enter jar capacity:6
# Enter min candies:5
# Enter candies to sold:4
# Sold: 4
# Available candies: 6
# Total sold 4
# Enter candies to sold:6
# Sold: 6
# Available candies: 6
# Total sold 10
